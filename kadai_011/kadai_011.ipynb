# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for i in range(0,9):
  print(array[i])

num = 0
wakusei = array[num]

while wakusei != "冥" :
  print(wakusei)
  num = num + 1
  wakusei = array[num]

print(wakusei)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
