# %%
class Human:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(f"{self.name}")
    print(f"{self.age}歳")

test = Human("テスト",3)
test.printinfo()
# Out:
# テスト
# 3歳
