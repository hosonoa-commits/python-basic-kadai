# %%
import random

var = random.randint(3,15)
print(f"var = {var}")

if var % 3 == 0 and var % 5 ==0:
    print("FizzBuzz")
elif var % 3 ==0:
    print("Fizz")
elif var % 5 ==0:
    print("Buzz")
else:
    print(var)
# Out:
# var = 15
# FizzBuzz
